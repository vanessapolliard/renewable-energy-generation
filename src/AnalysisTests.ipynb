# %% [markdown]
# ## Table names:
# * private_investment
# * net_generation
# * installed_capacity

# %%
import numpy as np
import pandas as pd
import psycopg2
import getpass

# %%
upass = getpass.getpass()
conn = psycopg2.connect(database="renewable_energy_generation", user="admin", password=upass, host="localhost", port="5432")
print("connected")
cur = conn.cursor()
# Out:
# ········
# connected

# %% [markdown]
# ## Look into generation/capacity ratio

# %% [markdown]
# * Different renewable energy sources have varying availability factors typically ranging from 80% to 98%. For this analysis I've used a conservative estimate of 75%. Each technology's ratio will vary by country and their natural differences in resources.
# * Private Participation in Infrastructure: Private parties have at least a 25 percent participation in the project and as such share in the risks of the project.
# * Developing Countries: countries categorized as low- and middle-income under World Bank classification.
# * Does not include small-scale projects.
# * Investment values in million USD

# %%
query_ratio = '''
    SELECT 
        g.country as country, 
        g.period as year,
        g.value as generated,
        c.bkwh_100 as capacity_100,
        c.bkwh_75 as capacity_75,
        (g.value/c.bkwh_100) as ratio_100,
        (g.value/c.bkwh_75) as ratio_75
    FROM installed_capacity as c
    JOIN net_generation as g
    ON c.country = g.country
    AND c.period = g.period
    WHERE g.value != 0
    AND c.bkwh_100 != 0
    ORDER BY country, year
    ;'''
cur.execute(query_ratio)

# %%
df_ratio = pd.DataFrame(cur.fetchall(), columns=['country', 'year', 'generated', 'capacity_100', 'capacity_75', 'ratio_100', 'ratio_75'])

# %%
df_gen_all = pd.DataFrame(cur.fetchall(), columns=['country', 'year', 'generated', 'capacity_100', 'capacity_75', 'ratio_100', 'ratio_75'])

# %%
df_ratio.head()
# Out:
#        country  year  generated  capacity_100  capacity_75  ratio_100  \
# 0  Afghanistan  1980      0.711       2.29512      1.72134   0.309788
# 1  Afghanistan  1981      0.721       2.26884      1.70163   0.317784
# 2  Afghanistan  1982      0.707       2.26884      1.70163   0.311613
# 3  Afghanistan  1983      0.746       2.38272      1.78704   0.313088
# 4  Afghanistan  1984      0.757       2.38272      1.78704   0.317704
#
#    ratio_75
# 0  0.413050
# 1  0.423711
# 2  0.415484
# 3  0.417450
# 4  0.423606

# %%
#drop dups
df_ratio.sort_values(['country','year'],inplace=True)
df_ratio.drop_duplicates(subset=['country', 'year'],inplace=True)

# %%
df_minyear = df_ratio.groupby("country",as_index=False)["year"].min()

# %%
df_minyear
# Out:
#                     country  year
# 0               Afghanistan  1980
# 1                    Africa  1980
# 2                   Albania  1980
# 3                   Algeria  1980
# 4                    Angola  1980
# 5                Antarctica  2008
# 6         AntiguaandBarbuda  2010
# 7                 Argentina  1980
# 8                   Armenia  1992
# 9                     Aruba  2009
# 10             Asia&Oceania  1980
# 11                Australia  1980
# 12   AustraliaandNewZealand  1980
# 13                  Austria  1980
# 14               Azerbaijan  1992
# 15                  Bahamas  2010
# 16                  Bahrain  2008
# 17               Bangladesh  1980
# 18                 Barbados  2010
# 19                  Belarus  1992
# 20                  Belgium  1980
# 21                   Belize  1995
# 22                    Benin  1996
# 23                   Bhutan  1980
# 24                  Bolivia  1980
# 25     BosniaandHerzegovina  1992
# 26                 Botswana  2013
# 27                   Brazil  1980
# 28                   Brunei  2012
# 29                 Bulgaria  1980
# ..                      ...   ...
# 203                Suriname  1980
# 204               Swaziland  1980
# 205                  Sweden  1980
# 206             Switzerland  1980
# 207                   Syria  1980
# 208                  Taiwan  1980
# 209              Tajikistan  1992
# 210                Tanzania  1980
# 211                Thailand  1980
# 212                    Togo  1980
# 213       TrinidadandTobago  2000
# 214                 Tunisia  1980
# 215                  Turkey  1980
# 216            Turkmenistan  1992
# 217      U.S.PacificIslands  1985
# 218                  Uganda  1980
# 219                 Ukraine  1992
# 220      UnitedArabEmirates  2009
# 221           UnitedKingdom  1980
# 222            UnitedStates  1980
# 223                 Uruguay  1980
# 224              Uzbekistan  1992
# 225                 Vanuatu  2010
# 226               Venezuela  1980
# 227                 Vietnam  1980
# 228           VirginIslands  2010
# 229                   World  1980
# 230                   Yemen  2010
# 231                  Zambia  1980
# 232                Zimbabwe  1980
#
# [233 rows x 2 columns]

# %%
df_generated = df_ratio['generated']
df_generated.pct_change()
#must set all 1980 vals to 0 or null
# Out:
# 0            NaN
# 1       0.014065
# 2      -0.019417
# 3       0.055163
# 4       0.014745
# 5       0.017173
# 6      -0.074026
# 7       0.060309
# 8      -0.015873
# 9       0.008065
# 10      0.008000
# 11     -0.096561
# 12     -0.307467
# 13     -0.006342
# 14     -0.006383
# 15     -0.117773
# 16     -0.123786
# 17     -0.108033
# 18     -0.068323
# 19      0.000000
# 20      0.040000
# 21      0.596154
# 22      0.114458
# 23      0.135135
# 24     -0.103175
# 25      0.044248
# 26      0.079661
# 27      0.174254
# 28     -0.275388
# 29      0.431892
#           ...
# 7511   -0.205637
# 7512    0.072177
# 7513    0.267018
# 7514    0.113684
# 7515   -0.059968
# 7516   -0.183442
# 7517   -0.386806
# 7518   -0.078143
# 7519    0.114251
# 7520    0.180265
# 7521   -0.018216
# 7522   -0.114653
# 7523    0.569049
# 7524    0.105137
# 7525   -0.080260
# 7526    0.275606
# 7527    0.401215
# 7528    0.030349
# 7529   -0.109587
# 7530    0.080337
# 7531    0.013884
# 7532    0.075220
# 7533   -0.047104
# 7534    0.068839
# 7535   -0.094896
# 7536    0.042581
# 7537   -0.070793
# 7538    0.079898
# 7539   -0.081223
# 7540   -0.391613
# Name: generated, Length: 6641, dtype: float64

# %%
df_gen_all.sort_values(['country','year'],inplace=True)
df_gen_all.drop_duplicates(subset=['country', 'year'],inplace=True)
df_gen_all['generation_change_percent'] = df_generated.pct_change()

# %%
df_gen_all
# Out:
#           country  year  generated  capacity_100  capacity_75  ratio_100  \
# 0     Afghanistan  1980    0.71100      2.295120     1.721340   0.309788
# 1     Afghanistan  1981    0.72100      2.268840     1.701630   0.317784
# 2     Afghanistan  1982    0.70700      2.268840     1.701630   0.311613
# 3     Afghanistan  1983    0.74600      2.382720     1.787040   0.313088
# 4     Afghanistan  1984    0.75700      2.382720     1.787040   0.317704
# 7529     Zimbabwe  2005    4.86700      6.666360     4.999770   0.730084
# 7530     Zimbabwe  2006    5.25800      6.666360     4.999770   0.788736
# 7531     Zimbabwe  2007    5.33100      7.174440     5.380830   0.743055
# 7532     Zimbabwe  2008    5.73200      7.297080     5.472810   0.785520
# 7533     Zimbabwe  2009    5.46200      7.323360     5.492520   0.745833
# 7534     Zimbabwe  2010    5.83800      7.358400     5.518800   0.793379
# 7535     Zimbabwe  2011    5.28400      7.428480     5.571360   0.711316
# 7536     Zimbabwe  2012    5.50900      7.472280     5.604210   0.737258
# 7537     Zimbabwe  2013    5.11900      7.481040     5.610780   0.684263
# 7538     Zimbabwe  2014    5.52800      7.656240     5.742180   0.722025
# 7539     Zimbabwe  2015    5.07900      7.673760     5.755320   0.661866
# 7540     Zimbabwe  2016    3.09000      7.770120     5.827590   0.397677
#
#       ratio_75  generation_change_percent
# 0     0.413050                        NaN
# 1     0.423711                   0.014065
# 2     0.415484                  -0.019417
# 3     0.417450                   0.055163
# 4     0.423606                   0.014745
# 5     0.417080                   0.017173
# 6     0.386205                  -0.074026
# 7     0.396788                   0.060309
# 8     0.390490                  -0.015873
# 9     0.390943                   0.008065
# 10    0.394070                   0.008000
# 11    0.356018                  -0.096561
# 12    0.246554                  -0.307467
# 13    0.244991                  -0.006342
# 14    0.243427                  -0.006383
# 15    0.214758                  -0.117773
# 16    0.188174                  -0.123786
# 17    0.167845                  -0.108033
# 18    0.156377                  -0.068323
# 19    0.156377                   0.000000
# 20    0.162632                   0.040000
# 21    0.197909                   0.596154
# 22    0.224667                   0.114458
# 23    0.256391                   0.135135
# 24    0.229938                  -0.103175
# 25    0.240113                   0.044248
# 26    0.259240                   0.079661
# 27    0.304414                   0.174254
# 28    0.220541                  -0.275388
# 29    0.315791                   0.431892
# ...        ...                        ...
# 7511  0.596324                  -0.205637
# 7512  0.639366                   0.072177
# 7513  0.810088                   0.267018
# 7514  0.902181                   0.113684
# 7515  0.848079                  -0.059968
# 7516  0.692506                  -0.183442
# 7517  0.424641                  -0.386806
# 7518  0.391458                  -0.078143
# 7519  0.436182                   0.114251
# 7520  0.489302                   0.180265
# 7521  0.480389                  -0.018216
# 7522  0.422772                  -0.114653
# 7523  0.663350                   0.569049
# 7524  0.603405                   0.105137
# 7525  0.554976                  -0.080260
# 7526  0.690871                   0.275606
# 7527  0.968059                   0.401215
# 7528  0.996841                   0.030349
# 7529  0.973445                  -0.109587
# 7530  1.051648                   0.080337
# 7531  0.990739                   0.013884
# 7532  1.047360                   0.075220
# 7533  0.994443                  -0.047104
# 7534  1.057839                   0.068839
# 7535  0.948422                  -0.094896
# 7536  0.983011                   0.042581
# 7537  0.912351                  -0.070793
# 7538  0.962701                   0.079898
# 7539  0.882488                  -0.081223
# 7540  0.530236                  -0.391613
#
# [6641 rows x 8 columns]

# %%
#remove percent change from first row of each country
df_gen_all.loc[df_gen_all.groupby('country')['generation_change_percent'].head(1).index, 'generation_change_percent'] = np.NaN

# 7511  0.596324                  -0.205637
# 7512  0.639366                   0.072177
# 7513  0.810088                   0.267018
# 7514  0.902181                   0.113684
# 7515  0.848079                  -0.059968
# 7516  0.692506                  -0.183442
# 7517  0.424641                  -0.386806
# 7518  0.391458                  -0.078143
# 7519  0.436182                   0.114251
# 7520  0.489302                   0.180265
# 7521  0.480389                  -0.018216
# 7522  0.422772                  -0.114653
# 7523  0.663350                   0.569049
# 7524  0.603405                   0.105137
# 7525  0.554976                  -0.080260
# 7526  0.690871                   0.275606
# 7527  0.968059                   0.401215
# 7528  0.996841                   0.030349
# 7529  0.973445                  -0.109587
# 7530  1.051648                   0.080337
# 7531  0.990739                   0.013884
# 7532  1.047360                   0.075220
# 7533  0.994443                  -0.047104
# 7534  1.057839                   0.068839
# 7535  0.948422                  -0.094896
# 7536  0.983011                   0.042581
# 7537  0.912351                  -0.070793
# 7538  0.962701                   0.079898
# 7539  0.882488                  -0.081223
# 7540  0.530236                  -0.391613

# %%
df_ratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6641 entries, 0 to 7540
# Data columns (total 7 columns):
# country         6641 non-null object
# year            6641 non-null int64
# generated       6641 non-null float64
# capacity_100    6641 non-null float64
# capacity_75     6641 non-null float64
# ratio_100       6641 non-null float64
# ratio_75        6641 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 415.1+ KB

# %%
df_ratio.describe()
# Out:
#               year    generated  capacity_100   capacity_75    ratio_100  \
# count  6641.000000  6641.000000   6641.000000   6641.000000  6641.000000
# mean   1999.463334    95.744886    232.944881    174.708661     0.493580
# std      10.677299   349.955306    883.011619    662.258714     1.508861
# min    1980.000000     0.000100      0.000088      0.000066     0.001359
# 25%    1991.000000     0.393000      0.928560      0.696420     0.285388
# 50%    2000.000000     3.396000      9.636000      7.227000     0.396024
# 75%    2009.000000    23.628640     62.975640     47.231730     0.506282
# max    2016.000000  5968.059207  17386.614108  13039.960581    50.456621
#
#           ratio_75
# count  6641.000000
# mean      0.658107
# std       2.011814
# min       0.001812
# 25%       0.380518
# 50%       0.528031
# 75%       0.675043
# max      67.275495

# %%
query_priv = '''
    SELECT 
        region,
        country,
        project_name,
        technology,
        total_investment as cost_usd_millions,
        percent_private,
        gov_payment_commitments as govt_contribution,
        capacity_year as year
    FROM private_investment
    ORDER BY region, country, year
    ;'''
cur.execute(query_priv)

# %%
df_private = pd.DataFrame(cur.fetchall(), columns=['region', 'country', 'project_name', 'technology', 'cost_usd_millions', 'percent_private', 'govt_contribution', 'year'])

# %%
df_private.head()
# Out:
#                   region   country                         project_name  \
# 0  East Asia and Pacific  Cambodia  Kirirom 1 and 3 Hydropower Stations
# 1  East Asia and Pacific  Cambodia  Stung Atay River Hydropower Station
# 2  East Asia and Pacific  Cambodia         ABC Phnom Penh Biomass Plant
# 3  East Asia and Pacific  Cambodia           Kamchay Hydropower Station
# 4  East Asia and Pacific  Cambodia  Kirirom 1 and 3 Hydropower Stations
#
#              technology cost_usd_millions percent_private govt_contribution  \
# 0  Hydro, Small (<50MW)                20             100                 0
# 1  Hydro, Large (>50MW)             255.3             100                 0
# 2               Biomass              6.33             100     Not Available
# 3  Hydro, Large (>50MW)               280             100                 0
# 4  Hydro, Small (<50MW)              47.1             100     Not Available
#
#    year
# 0  2001
# 1  2007
# 2  2007
# 3  2007
# 4  2008

# %%
df_private.describe()
# Out:
#                                  region country  \
# count                              1699    1699
# unique                                6      85
# top     Latin America and the Caribbean  Brazil
# freq                                523     315
#
#                                           project_name     technology  \
# count                                             1699           1699
# unique                                            1543             16
# top     Companhia de Geracao de Energia Eletrica Tiete  Wind, Onshore
# freq                                                14            511
#
#        cost_usd_millions percent_private govt_contribution  year
# count               1699            1699              1699  1699
# unique               955              66               102    22
# top                    0             100     Not Available  2012
# freq                 256            1411               874   680

# %%
df_techtype = df_private.groupby('technology').count()
df_techtype
# Out:
#                                 region  country  project_name  \
# technology
# Biogas                               6        6             6
# Biomass                             74       74            74
# Geothermal                          47       47            47
# Hydro, Large (>50MW)               320      320           320
# Hydro, Small (<50MW)               413      413           413
# Natural Gas, Steam, Solar, CSP       1        1             1
# Natural Gas, Steam, Solar, PV        1        1             1
# Solar, CPV                           1        1             1
# Solar, CSP                          14       14            14
# Solar, PV                          193      193           193
# Waste                              114      114           114
# Wave                                 1        1             1
# Wind, Offshore                       1        1             1
# Wind, Onshore                      511      511           511
# Wind, Onshore, Not Applicable        1        1             1
# Wind, Onshore, Solar, PV             1        1             1
#
#                                 cost_usd_millions  percent_private  \
# technology
# Biogas                                          6                6
# Biomass                                        74               74
# Geothermal                                     47               47
# Hydro, Large (>50MW)                          320              320
# Hydro, Small (<50MW)                          413              413
# Natural Gas, Steam, Solar, CSP                  1                1
# Natural Gas, Steam, Solar, PV                   1                1
# Solar, CPV                                      1                1
# Solar, CSP                                     14               14
# Solar, PV                                     193              193
# Waste                                         114              114
# Wave                                            1                1
# Wind, Offshore                                  1                1
# Wind, Onshore                                 511              511
# Wind, Onshore, Not Applicable                   1                1
# Wind, Onshore, Solar, PV                        1                1
#
#                                 govt_contribution  year
# technology
# Biogas                                          6     6
# Biomass                                        74    74
# Geothermal                                     47    47
# Hydro, Large (>50MW)                          320   320
# Hydro, Small (<50MW)                          413   413
# Natural Gas, Steam, Solar, CSP                  1     1
# Natural Gas, Steam, Solar, PV                   1     1
# Solar, CPV                                      1     1
# Solar, CSP                                     14    14
# Solar, PV                                     193   193
# Waste                                         114   114
# Wave                                            1     1
# Wind, Offshore                                  1     1
# Wind, Onshore                                 511   511
# Wind, Onshore, Not Applicable                   1     1
# Wind, Onshore, Solar, PV                        1     1

# %%
df_techtype_avg = df_private.groupby('technology').mean()
df_techtype_avg
# Out:
#                                 cost_usd_millions
# technology
# Biogas                                  43.850000
# Biomass                                 51.656351
# Geothermal                             238.194681
# Hydro, Large (>50MW)                   443.745863
# Hydro, Small (<50MW)                    41.274019
# Natural Gas, Steam, Solar, CSP         314.700000
# Natural Gas, Steam, Solar, PV          158.200000
# Solar, CPV                             720.000000
# Solar, CSP                             457.242857
# Solar, PV                              101.943316
# Waste                                   41.596316
# Wave                                    65.000000
# Wind, Offshore                          68.000000
# Wind, Onshore                          133.113669
# Wind, Onshore, Not Applicable          378.200000
# Wind, Onshore, Solar, PV               280.000000

# %%
df_techtypecost = df_private.groupby('technology',as_index=False)['cost_usd_millions'].sum()
df_techtypecost
# Out:
#                         technology  cost_usd_millions
# 0                           Biogas            263.100
# 1                          Biomass           3822.570
# 2                       Geothermal          11195.150
# 3             Hydro, Large (>50MW)         141998.676
# 4             Hydro, Small (<50MW)          17046.170
# 5   Natural Gas, Steam, Solar, CSP            314.700
# 6    Natural Gas, Steam, Solar, PV            158.200
# 7                       Solar, CPV            720.000
# 8                       Solar, CSP           6401.400
# 9                        Solar, PV          19675.060
# 10                           Waste           4741.980
# 11                            Wave             65.000
# 12                  Wind, Offshore             68.000
# 13                   Wind, Onshore          68021.085
# 14   Wind, Onshore, Not Applicable            378.200
# 15        Wind, Onshore, Solar, PV            280.000

# %%
df_techtypecost['tech_category'],df_techtypecost['technology'] = df_techtypecost['technology'].str.split(',',1).str

# %%
df_techtypecost
# Out:
#                   technology  cost_usd_millions tech_category
# 0                        NaN            263.100        Biogas
# 1                        NaN           3822.570       Biomass
# 2                        NaN          11195.150    Geothermal
# 3              Large (>50MW)         141998.676         Hydro
# 4              Small (<50MW)          17046.170         Hydro
# 5          Steam, Solar, CSP            314.700   Natural Gas
# 6           Steam, Solar, PV            158.200   Natural Gas
# 7                        CPV            720.000         Solar
# 8                        CSP           6401.400         Solar
# 9                         PV          19675.060         Solar
# 10                       NaN           4741.980         Waste
# 11                       NaN             65.000          Wave
# 12                  Offshore             68.000          Wind
# 13                   Onshore          68021.085          Wind
# 14   Onshore, Not Applicable            378.200          Wind
# 15        Onshore, Solar, PV            280.000          Wind

# %%
df_private.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1699 entries, 0 to 1698
# Data columns (total 7 columns):
# region               1699 non-null object
# country              1699 non-null object
# technology           1699 non-null object
# cost_usd_millions    1699 non-null object
# percent_private      1699 non-null object
# govt_contribution    1699 non-null object
# year                 1699 non-null object
# dtypes: object(7)
# memory usage: 93.0+ KB

# %%
conn.commit()

# %%
conn.close()

# %% [markdown]
# ## Graph 75% ratio by country over time

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
fig, ax = plt.subplots()
x = np.linspace(1980,2016,7)
xvals = df_ratio[df_ratio['country']== 'Greece']['year']
yvals = df_ratio[df_ratio['country']== 'Greece']['ratio_75']
ax.plot(xvals,yvals)
ax.set_xticks(x)
ax.set_xlabel("Years")
ax.set_ylabel("Generation Ratio (75% availability)");

# %%
def plot_generation(country_name):
    fig, ax = plt.subplots()
    x = np.linspace(1980,2016,7)
    xvals = df_ratio[df_ratio['country']== country_name]['year']
    yvals = df_ratio[df_ratio['country']== country_name]['generated']
    ax.plot(xvals,yvals)
    ax.set_xticks(x)
    ax.set_xlabel("Years")
    ax.set_ylabel("Generation (billion kwh)")
    ax.set_title("{}".format(country_name));

# %%
plot_generation('Romania')

# %%
# 852  Brazil  2015  426.63700    995.951556   746.963667   0.428371  0.571162
# 856  Brazil  2016  461.31900   1068.282876   801.212157   0.431832  0.575776

# %% [markdown]
# ## Graph investment totals

# %%
df_private["cost_usd_millions"] = pd.to_numeric(df_private["cost_usd_millions"])

# %%
df_costbycountry = df_private.groupby('country',as_index=False)['cost_usd_millions'].sum()
df_costbycountry.sort_values(by='cost_usd_millions',ascending=False,inplace=True)

# %%
fig, ax = plt.subplots()
x = np.linspace(1980,2016,7)
xvals = df_costbycountry['country'][:14]
yvals = df_costbycountry['cost_usd_millions'][:14]
ax.bar(xvals,yvals)
ax.set_xlabel("Country")
plt.xticks(rotation='vertical')
ax.set_ylabel("Private Investments (Million USD)");

# %%
df_costbycountry[:14]
# Out:
#          country  cost_usd_millions
# 12        Brazil          99336.880
# 33         India          17198.860
# 19         China          16324.840
# 77        Turkey          12320.240
# 41       Lao PDR          11768.020
# 18         Chile          11551.100
# 62   Philippines           9624.980
# 63       Romania           8556.030
# 34     Indonesia           6968.500
# 4      Argentina           6845.400
# 70  South Africa           5680.600
# 79       Ukraine           4918.900
# 13      Bulgaria           4302.485
# 49        Mexico           3913.700

# %% [markdown]
# ## Median/mean project investments by region

# %% [markdown]
# ## Add count of projects by year to ratio graphs

# %% [markdown]
# Technology projects by region/country - do type of technology project have a significant impact to generation or generation ratio?

# %% [markdown]
# ## Other Exploration

# %%
pd.plotting.scatter_matrix(df_ratio,alpha=0.2, figsize=(10, 10));
plt.show()

# %%
pd.plotting.scatter_matrix(df_private,alpha=0.2, figsize=(10, 10));
plt.show()

# %%
# need to create a dataframe that has percent change in generation, 
# project summary combined (cost,count,type)

# %% [markdown]
# ## ReadMe Summary
# * countries with largest private investments in renewable energy sources
# * project counts plotted over generation graphs
# * all ratio graphs plotted
# * project type for each of top 14 countries
# * number of projects by region compared to other regions - NO (can't normalize)
# * project type by region
# * project type by level of income
# *  by level of income

# %% [markdown]
# # CLEAN CODE ONLY

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import psycopg2
import getpass
plt.style.use('ggplot')
colors = ["#0dba86", "#0d98ba","#0d42ba"]

# %%
upass = getpass.getpass()
conn = psycopg2.connect(database="renewable_energy_generation", user="admin", password=upass, host="localhost", port="5432")
print("connected")
cur = conn.cursor()
# Out:
# ········
# connected

# %% [markdown]
# ## 1st DF/Query

# %%
query_gen_cap = '''
    SELECT 
        g.country as country, 
        g.period as year,
        g.value as generated,
        c.value as capacity,
        c.bkwh_100 as capacity_100,
        c.bkwh_75 as capacity_75,
        (g.value/c.bkwh_100) as ratio_100,
        (g.value/c.bkwh_75) as ratio_75
    FROM installed_capacity as c
    JOIN net_generation as g
    ON c.country = g.country
    AND c.period = g.period
    WHERE g.value != 0
    AND c.bkwh_100 != 0
    ORDER BY country, year
    ;'''
cur.execute(query_gen_cap)

# %%
conn.close()

# %%
df_gen_cap = pd.DataFrame(cur.fetchall(), columns=['country', 'year', 'generated_kwh', 'capacity_kw','capacity_kwh_100', 'capacity_kwh_75', 'ratio_100', 'ratio_75'])

# %%
df_gen_cap.sort_values(['country','year'],inplace=True)
df_gen_cap.drop_duplicates(subset=['country', 'year'],inplace=True)

#add % change for capacity, generation, ratio
df_gen = df_gen_cap['generated_kwh']
df_cap = df_gen_cap['capacity_kw']
df_ratio = df_gen_cap['ratio_75']
df_gen_cap['generation_change_percent'] = df_gen.pct_change()
df_gen_cap['capacity_change_percent'] = df_cap.pct_change()
df_gen_cap['ratio_change_percent'] = df_ratio.pct_change()

# %%
#remove percent change from first row of each country
df_gen_cap.loc[df_gen_cap.groupby('country')['generation_change_percent'].head(1).index, 'generation_change_percent'] = np.NaN
df_gen_cap.loc[df_gen_cap.groupby('country')['capacity_change_percent'].head(1).index, 'capacity_change_percent'] = np.NaN
df_gen_cap.loc[df_gen_cap.groupby('country')['ratio_change_percent'].head(1).index, 'ratio_change_percent'] = np.NaN

# %%
df_gen_cap
# Out:
#           country  year  generated_kwh  capacity_kw  capacity_kwh_100  \
# 0     Afghanistan  1980        0.71100      0.26200          2.295120
# 1     Afghanistan  1981        0.72100      0.25900          2.268840
# 2     Afghanistan  1982        0.70700      0.25900          2.268840
# 3     Afghanistan  1983        0.74600      0.27200          2.382720
# 4     Afghanistan  1984        0.75700      0.27200          2.382720
# 5     Afghanistan  1985        0.77000      0.28100          2.461560
# 6     Afghanistan  1986        0.71300      0.28100          2.461560
# 7     Afghanistan  1987        0.75600      0.29000          2.540400
# 8     Afghanistan  1988        0.74400      0.29000          2.540400
# 9     Afghanistan  1989        0.75000      0.29200          2.557920
# 10    Afghanistan  1990        0.75600      0.29200          2.557920
# 11    Afghanistan  1991        0.68300      0.29200          2.557920
# 12    Afghanistan  1992        0.47300      0.29200          2.557920
# 13    Afghanistan  1993        0.47000      0.29200          2.557920
# 14    Afghanistan  1994        0.46700      0.29200          2.557920
# 15    Afghanistan  1995        0.41200      0.29200          2.557920
# 16    Afghanistan  1996        0.36100      0.29200          2.557920
# 17    Afghanistan  1997        0.32200      0.29200          2.557920
# 18    Afghanistan  1998        0.30000      0.29200          2.557920
# 19    Afghanistan  1999        0.30000      0.29200          2.557920
# 20    Afghanistan  2000        0.31200      0.29200          2.557920
# 21    Afghanistan  2001        0.49800      0.38300          3.355080
# 22    Afghanistan  2002        0.55500      0.37600          3.293760
# 23    Afghanistan  2003        0.63000      0.37400          3.276240
# 24    Afghanistan  2004        0.56500      0.37400          3.276240
# 25    Afghanistan  2005        0.59000      0.37400          3.276240
# 26    Afghanistan  2006        0.63700      0.37400          3.276240
# 27    Afghanistan  2007        0.74800      0.37400          3.276240
# 28    Afghanistan  2008        0.54201      0.37407          3.276853
# 29    Afghanistan  2009        0.77610      0.37407          3.276853
# ...           ...   ...            ...          ...               ...
# 7511     Zimbabwe  1987        2.48000      0.63300          5.545080
# 7512     Zimbabwe  1988        2.65900      0.63300          5.545080
# 7513     Zimbabwe  1989        3.36900      0.63300          5.545080
# 7515                 0.000000             -0.059968
# 7516                 0.000000             -0.183442
# 7517                 0.000000             -0.386806
# 7518                 0.000000             -0.078143
# 7519                 0.000000              0.114251
# 7520                 0.052133              0.121783
# 7521                 0.000000             -0.018216
# 7522                 0.006006             -0.119938
# 7523                 0.000000              0.569049
# 7524                 0.214925             -0.090366
# 7525                 0.000000             -0.080260
# 7526                 0.024693              0.244867
# 7527                 0.000000              0.401215
# 7528                 0.000599              0.029731
# 7529                -0.088186             -0.023470
# 7530                 0.000000              0.080337
# 7531                 0.076216             -0.057918
# 7532                 0.017094              0.057149
# 7533                 0.003601             -0.050523
# 7534                 0.004785              0.063750
# 7535                 0.009524             -0.103434
# 7536                 0.005896              0.036470
# 7537                 0.001172             -0.071881
# 7538                 0.023419              0.055187
# 7539                 0.002288             -0.083321
# 7540                 0.012557             -0.399157
#
# [6641 rows x 11 columns]

# %% [markdown]
# ## 2nd DF/Query

# %%
query_priv_inv = '''
    SELECT 
        region,
        country,
        income_group,
        project_name,
        technology,
        total_investment as cost_usd_millions,
        investment_year as year,
        capacity as capacity_mw
    FROM private_investment
    ORDER BY region, country, year
    ;'''
cur.execute(query_priv_inv)

# %%
df_private_inv = pd.DataFrame(cur.fetchall(), columns=['region', 'country', 'income_group',
                                                       'project_name','technology', 
                                                       'cost_usd_millions', 
                                                        'year', 'capacity_mw'])

# %%
test_df = df_private_inv.groupby('year',as_index = False).count()

# %%
df_private_inv["cost_usd_millions"] = pd.to_numeric(df_private_inv["cost_usd_millions"])
df_private_inv["year"] = pd.to_numeric(df_private_inv["year"])
df_private_inv.loc[df_private_inv['capacity_mw'] == 'Not Available','capacity_mw'] = np.nan
df_private_inv["capacity_mw"] = pd.to_numeric(df_private_inv["capacity_mw"])

# %%
df_private_inv["capacity_kw"] = df_private_inv["capacity_mw"]*1000

# %%
conn.close()

# %% [markdown]
# ## INV Investment $ in top 16 countries

# %%
df_inv_country = df_private_inv.groupby('country',as_index=False)['cost_usd_millions'].sum()
df_inv_country.sort_values(by='cost_usd_millions',ascending=False,inplace=True)

# %%
# pull top 16 to work with in other places:
df_top16 = df_inv_country['country'][:16]
df_top16.replace('Lao PDR','Laos',inplace=True) #adjust to match other dataset
df_top16.replace('South Africa','SouthAfrica',inplace=True)
top16 = list(df_top16)

# %%
fig, ax = plt.subplots()
x = np.linspace(1980,2016,7)
xvals = df_inv_country['country'][:16]
yvals = df_inv_country['cost_usd_millions'][:16]
ax.bar(xvals,yvals,color=colors[0])
ax.set_xlabel("Country")
plt.xticks(rotation='vertical')
ax.set_ylabel("Private Investments (Million USD)")
ax.set_title("Top 16 Countries' Private Investment");

# %% [markdown]
# ## INV Investment by country classification and tech category

# %%
df_inv_tech_cat = df_private_inv.copy()
df_inv_tech_cat['tech_category'],df_inv_tech_cat['technology'] = df_inv_tech_cat['technology'].str.split(',',1).str

# %%
df_inv_tech_cat_agg = df_inv_tech_cat.groupby(['income_group','tech_category'],as_index=False)['cost_usd_millions'].sum()

# %%
pivot_df = df_inv_tech_cat_agg.pivot(index='income_group', columns='tech_category', values='cost_usd_millions')
pivot_df.plot.bar(stacked=True, colormap = 'tab10', figsize=(10,7));

# %% [markdown]
# ## INV avg capacity per USD investment by tech type (all)

# %%
df_inv_cap_class = df_inv_tech_cat.copy()
df_inv_cap_class_agg = df_inv_cap_class.groupby('tech_category',as_index=False).sum()
df_inv_cap_class_agg['capacity_per_usd'] = df_inv_cap_class_agg['capacity_kw']/df_inv_cap_class_agg['cost_usd_millions']
df_inv_cap_class_agg.sort_values(by='capacity_per_usd',ascending=False,inplace=True)

# %%
fig, ax = plt.subplots()
ax.bar(df_inv_cap_class_agg['tech_category'],df_inv_cap_class_agg['capacity_per_usd'],color=colors[1])
plt.xticks(rotation='vertical')
ax.set_title("Capacity (KW) per $ Investment")
;
# Out:
# ''

# %% [markdown]
# ## GEN, INV Capacity over time with projects overlay (top 16)

# %%
df_capacity_plt = df_gen_cap.copy()

# %%
def plot_capacity(ax, country_name):
    x = np.linspace(1980,2016,7)
    xvals = df_capacity_plt[df_capacity_plt['country']== country_name]['year']
    yvals = df_capacity_plt[df_capacity_plt['country']== country_name]['capacity_kw']
    ax.plot(xvals,yvals,color=colors[2])
    ax.set_xticks(x)
    ax.set_xlabel("Years")
    ax.set_ylabel("Capacity (kw)")
    ax.set_title("{}".format(country_name));

# %%
fig, axs = plt.subplots(4, 4, figsize=(14, 14))

for ax, country in zip(axs.flatten(),top16):
    plot_capacity(ax, country)
plt.tight_layout()

# %% [markdown]
# ## GEN, INV ratio with projects overlay (top 16)

# %%
df_ratio_plt = df_gen_cap.copy()

# %%
def plot_ratio(ax, country_name):
    x = np.linspace(1980,2016,7)
    xvals = df_ratio_plt[df_ratio_plt['country']== country_name]['year']
    yvals = df_ratio_plt[df_ratio_plt['country']== country_name]['ratio_75']
    ax.plot(xvals,yvals,color=colors[0])
    ax.set_xticks(x)
    ax.set_xlabel("Years")
    ax.set_ylabel("Generation/Capacity Ratio")
    ax.set_title("{}".format(country_name));

# %%
fig, axs = plt.subplots(4, 4, figsize=(14, 14))

for ax, country in zip(axs.flatten(),top16):
    plot_ratio(ax, country)
plt.tight_layout()

# %% [markdown]
# ## GEN, INV Percent capacity change (top 16 as line series)

# %%
def plot_capacity_change(ax, country_name):
    x = np.linspace(1980,2016,7)
    #y = np.linspace(-0.3,1.3,10)
    xvals = df_capacity_plt[df_capacity_plt['country']== country_name]['year']
    yvals = df_capacity_plt[df_capacity_plt['country']== country_name]['capacity_change_percent']
    ax.plot(xvals,yvals,color=colors[1])
    ax.set_xticks(x)
    #ax.set_yticks(y) Create overlay graph for this
    ax.set_xlabel("Years")
    ax.set_ylabel("Capacity Change %")
    ax.set_title("{}".format(country_name));

# %%
fig, axs = plt.subplots(4, 4, figsize=(14, 14))

for ax, country in zip(axs.flatten(),top16):
    plot_capacity_change(ax, country)
plt.tight_layout()

# %% [markdown]
# ## Plot % Change Overlay of 16 Countries

# %%
colors2 = ['#279989','#1a405a','#ffbfb7','#f25e60','#eac05f','#bcccce','#95b211','#fe8402','#cbc4d8','#a95292','#244c96','#071d49','#dcd4e5','#0dba86','#0d98ba','#0d42ba']
def plot_capacity_change_single(country_name,color_idx):
    x = np.linspace(1980,2016,7)
    y = np.linspace(-0.3,1.5,10)
    xvals = df_capacity_plt[df_capacity_plt['country']== country_name]['year']
    yvals = df_capacity_plt[df_capacity_plt['country']== country_name]['capacity_change_percent']
    ax.plot(xvals,yvals,label=country_name,linewidth=1,color=colors2[color_idx])
    ax.set_xticks(x)
    ax.set_yticks(y)
    ax.set_xlabel("Years")
    ax.set_ylabel("Capacity Change %")
    ax.set_title("Capacity Change %");

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots(1, 1, figsize=(14, 7))
for idx, country in enumerate(top16):
    plot_capacity_change_single(country,idx)
plt.legend()
plt.show()

# %% [markdown]
# ## GEN Correlation between generation and capacity

# %%
df_private_inv.corr()
# Out:
#                    cost_usd_millions      year  capacity_mw  capacity_kw
# cost_usd_millions           1.000000  0.032496     0.595798     0.595798
# year                        0.032496  1.000000    -0.051941    -0.051941
# capacity_mw                 0.595798 -0.051941     1.000000     1.000000
# capacity_kw                 0.595798 -0.051941     1.000000     1.000000

# %%
df_gen_cap.corr()
# Out:
#                                year  generated_kwh  capacity_kw  \
# year                       1.000000       0.052299     0.071362
# generated_kwh              0.052299       1.000000     0.989766
# capacity_kw                0.071362       0.989766     1.000000
# capacity_kwh_100           0.071362       0.989766     1.000000
# capacity_kwh_75            0.071362       0.989766     1.000000
# ratio_100                 -0.044251      -0.011968    -0.014437
# ratio_75                  -0.044251      -0.011968    -0.014437
# generation_change_percent  0.037100      -0.018384    -0.017556
# capacity_change_percent    0.013493      -0.009421    -0.008585
# ratio_change_percent       0.015789      -0.010889    -0.011007
#
#                            capacity_kwh_100  capacity_kwh_75  ratio_100  \
# year                               0.071362         0.071362  -0.044251
# generated_kwh                      0.989766         0.989766  -0.011968
# capacity_kw                        1.000000         1.000000  -0.014437
# capacity_kwh_100                   1.000000         1.000000  -0.014437
# capacity_kwh_75                    1.000000         1.000000  -0.014437
# ratio_100                         -0.014437        -0.014437   1.000000
# ratio_75                          -0.014437        -0.014437   1.000000
# generation_change_percent         -0.017556        -0.017556   0.095379
# capacity_change_percent           -0.008585        -0.008585  -0.006525
# ratio_change_percent              -0.011007        -0.011007   0.073574
#
#                            ratio_75  generation_change_percent  \
# year                      -0.044251                   0.037100
# generated_kwh             -0.011968                  -0.018384
# capacity_kw               -0.014437                  -0.017556
# capacity_kwh_100          -0.014437                  -0.017556
# capacity_kwh_75           -0.014437                  -0.017556
# ratio_100                  1.000000                   0.095379
# ratio_75                   1.000000                   0.095379
# generation_change_percent  0.095379                   1.000000
# capacity_change_percent   -0.006525                   0.096399
# ratio_change_percent       0.073574                   0.595499
#
#                            capacity_change_percent  ratio_change_percent
# year                                      0.013493              0.015789
# generated_kwh                            -0.009421             -0.010889
# capacity_kw                              -0.008585             -0.011007
# capacity_kwh_100                         -0.008585             -0.011007
# capacity_kwh_75                          -0.008585             -0.011007
# ratio_100                                -0.006525              0.073574
# ratio_75                                 -0.006525              0.073574
# generation_change_percent                 0.096399              0.595499
# capacity_change_percent                   1.000000             -0.016258
# ratio_change_percent                     -0.016258              1.000000

# %% [markdown]
# ## GEN, INV Correlation between % capacity change & investment amount

# %% [markdown]
# ## Correlation between % changes in gen/cap and investment summary (count, amount, type)

# %%
# need to create new DF with % changes AND investment summary - count, amount, type

# %%
df_private_inv.head()
# Out:
#                   region   country income_group  \
# 0  East Asia and Pacific  Cambodia   Low income
# 1  East Asia and Pacific  Cambodia   Low income
# 2  East Asia and Pacific  Cambodia   Low income
# 3  East Asia and Pacific  Cambodia   Low income
# 4  East Asia and Pacific  Cambodia   Low income
#
#                           project_name            technology  \
# 0  Kirirom 1 and 3 Hydropower Stations  Hydro, Small (<50MW)
# 1  Stung Atay River Hydropower Station  Hydro, Large (>50MW)
# 2         ABC Phnom Penh Biomass Plant               Biomass
# 3           Kamchay Hydropower Station  Hydro, Large (>50MW)
# 4  Kirirom 1 and 3 Hydropower Stations  Hydro, Small (<50MW)
#
#    cost_usd_millions  year  capacity_mw  capacity_kw
# 0              20.00  2001         12.0      12000.0
# 1             255.30  2007        120.0     120000.0
# 2               6.33  2007          2.0       2000.0
# 3             280.00  2007        193.0     193000.0
# 4              47.10  2008         30.0      30000.0

# %%
df_gen_cap.head()
# Out:
#        country  year  generated_kwh  capacity_kw  capacity_kwh_100  \
# 0  Afghanistan  1980          0.711        0.262           2.29512
# 1  Afghanistan  1981          0.721        0.259           2.26884
# 2  Afghanistan  1982          0.707        0.259           2.26884
# 3  Afghanistan  1983          0.746        0.272           2.38272
# 4  Afghanistan  1984          0.757        0.272           2.38272
#
#    capacity_kwh_75  ratio_100  ratio_75  generation_change_percent  \
# 0          1.72134   0.309788  0.413050                        NaN
# 1          1.70163   0.317784  0.423711                   0.014065
# 2          1.70163   0.311613  0.415484                  -0.019417
# 3          1.78704   0.313088  0.417450                   0.055163
# 4          1.78704   0.317704  0.423606                   0.014745
#
#    capacity_change_percent  ratio_change_percent
# 0                      NaN                   NaN
# 1                -0.011450              0.025811
# 2                 0.000000             -0.019417
# 3                 0.050193              0.004732
# 4                 0.000000              0.014745

# %%
df_inv_agg = df_private_inv.copy()
d = {'project_name':'project_count', 'cost_usd_millions':'total_investments'}
df_inv_agg = df_inv_agg.groupby(['country','year'],as_index=False).agg({'project_name':'count','cost_usd_millions':'sum'}).rename(columns=d)

# %%
df_gen_cap_inv = pd.merge(df_gen_cap, df_inv_agg,  how='left', left_on=['country','year'], right_on = ['country','year'])

# %%
df_gen_cap_inv[df_gen_cap_inv['country']=='Brazil']
# Out:
#     country  year  generated_kwh  capacity_kw  capacity_kwh_100  \
# 712  Brazil  1980      130.35880     27.50000        240.900000
# 732       418.784940   0.553754  0.738339                   0.036078
# 733       428.416560   0.480045  0.640060                  -0.113171
# 734       446.779710   0.492711  0.656948                   0.070380
# 735       463.270410   0.509176  0.678902                   0.071561
# 736       474.003490   0.522348  0.696463                   0.049635
# 737       488.985390   0.533400  0.711200                   0.053434
# 738       509.943690   0.529878  0.706504                   0.035975
# 739       533.608830   0.546672  0.728896                   0.079572
# 740       545.395410   0.531516  0.708688                  -0.006248
# 741       557.970390   0.552339  0.736452                   0.063136
# 742       588.304080   0.551920  0.735893                   0.053565
# 743       610.261020   0.564092  0.752122                   0.060199
# 744       635.359077   0.532946  0.710595                  -0.016358
# 745       664.181667   0.490145  0.653526                  -0.038591
# 746       706.065417   0.454552  0.606070                  -0.014134
# 747       746.963667   0.428371  0.571162                  -0.003010
# 748       801.212157   0.431832  0.575776                   0.081292
#
#      capacity_change_percent  ratio_change_percent  project_count  \
# 712                      NaN                   NaN            NaN
# 713                 0.128036             -0.106194            NaN
# 714                 0.063860              0.015611            NaN
# 715                 0.031089              0.045321            NaN
# 716                 0.026302              0.069255            NaN
# 717                 0.061679              0.007349            NaN
# 718                 0.019122              0.004529            NaN
# 719                 0.067300             -0.045340            NaN
# 720                 0.047088              0.022057            NaN
# 721                 0.060813             -0.031770            NaN
# 722                 0.017010             -0.004624            NaN
# 723                 0.023223              0.029352            NaN
# 724                 0.023447              0.005588            NaN
# 725                 0.018676              0.032307            1.0
# 726                 0.027325              0.006159            1.0
# 727                 0.027700              0.017781            1.0
# 728                 0.041258              0.008608            NaN
# 729                 0.028861              0.021291            3.0
# 730                 0.032545              0.011171            4.0
# 731                 0.039430             -0.030221            3.0
# 732                 0.080428             -0.041049           12.0
# 733                 0.022999             -0.133108           11.0
# 734                 0.042863              0.026386           10.0
# 735                 0.036910              0.033418           12.0
# 736                 0.023168              0.025868            5.0
# 737                 0.031607              0.021159           25.0
# 738                 0.042861             -0.006602           17.0
# 739                 0.046407              0.031694           16.0
# 740                 0.022088             -0.027724           32.0
# 741                 0.023057              0.039176           36.0
# 742                 0.054364             -0.000758           19.0
# 743                 0.037322              0.022054           45.0
# 744                 0.041127             -0.055214           62.0
# 745                 0.045364             -0.080312            NaN
# 746                 0.063061             -0.072615            NaN
# 747                 0.057924             -0.057598            NaN
# 748                 0.072625              0.008079            NaN
#
#      total_investments
# 712                NaN
# 713                NaN
# 714                NaN
# 715                NaN
# 716                NaN
# 717                NaN
# 718                NaN
# 719                NaN
# 720                NaN
# 721                NaN
# 722                NaN
# 723                NaN
# 724                NaN
# 725               0.00
# 726             210.00
# 727              12.00
# 728                NaN
# 729            1477.00
# 730            1048.60
# 731            2588.10
# 732            2581.00
# 733            1282.80
# 734             249.60
# 735            1311.93
# 736             157.20
# 737            1752.15
# 738            1366.60
# 739            4902.10
# 740            4121.10
# 741           20888.00
# 742            3866.90
# 743            7525.20
# 744           43996.60
# 745                NaN
# 746                NaN
# 747                NaN
# 748                NaN

# %%
df_gen_cap_inv.corr()
# Out:
#                                year  generated_kwh  capacity_kw  \
# year                       1.000000       0.052299     0.071362
# generated_kwh              0.052299       1.000000     0.989766
# capacity_kw                0.071362       0.989766     1.000000
# capacity_kwh_100           0.071362       0.989766     1.000000
# capacity_kwh_75            0.071362       0.989766     1.000000
# ratio_100                 -0.044251      -0.011968    -0.014437
# ratio_75                  -0.044251      -0.011968    -0.014437
# generation_change_percent  0.037100      -0.018384    -0.017556
# capacity_change_percent    0.013493      -0.009421    -0.008585
# ratio_change_percent       0.015789      -0.010889    -0.011007
# project_count              0.303426       0.447866     0.424070
# total_investments          0.179092       0.330025     0.263013
#
#                            capacity_kwh_100  capacity_kwh_75  ratio_100  \
# year                               0.071362         0.071362  -0.044251
# generated_kwh                      0.989766         0.989766  -0.011968
# capacity_kw                        1.000000         1.000000  -0.014437
# capacity_kwh_100                   1.000000         1.000000  -0.014437
# capacity_kwh_75                    1.000000         1.000000  -0.014437
# ratio_100                         -0.014437        -0.014437   1.000000
# ratio_75                          -0.014437        -0.014437   1.000000
# generation_change_percent         -0.017556        -0.017556   0.095379
# capacity_change_percent           -0.008585        -0.008585  -0.006525
# ratio_change_percent              -0.011007        -0.011007   0.073574
# project_count                      0.424070         0.424070  -0.083077
# total_investments                  0.263013         0.263013   0.053061
#
#                            ratio_75  generation_change_percent  \
# year                      -0.044251                   0.037100
# generated_kwh             -0.011968                  -0.018384
# capacity_kw               -0.014437                  -0.017556
# capacity_kwh_100          -0.014437                  -0.017556
# capacity_kwh_75           -0.014437                  -0.017556
# ratio_100                  1.000000                   0.095379
# ratio_75                   1.000000                   0.095379
# generation_change_percent  0.095379                   1.000000
# capacity_change_percent   -0.006525                   0.096399
# ratio_change_percent       0.073574                   0.595499
# project_count             -0.083077                  -0.004803
# total_investments          0.053061                  -0.024264
#
#                            capacity_change_percent  ratio_change_percent  \
# year                                      0.013493              0.015789
# generated_kwh                            -0.009421             -0.010889
# capacity_kw                              -0.008585             -0.011007
# capacity_kwh_100                         -0.008585             -0.011007
# capacity_kwh_75                          -0.008585             -0.011007
# ratio_100                                -0.006525              0.073574
# ratio_75                                 -0.006525              0.073574
# generation_change_percent                 0.096399              0.595499
# capacity_change_percent                   1.000000             -0.016258
# ratio_change_percent                     -0.016258              1.000000
# project_count                             0.195541             -0.049267
# total_investments                         0.019629             -0.031054
#
#                            project_count  total_investments
# year                            0.303426           0.179092
# generated_kwh                   0.447866           0.330025
# capacity_kw                     0.424070           0.263013
# capacity_kwh_100                0.424070           0.263013
# capacity_kwh_75                 0.424070           0.263013
# ratio_100                      -0.083077           0.053061
# ratio_75                       -0.083077           0.053061
# generation_change_percent      -0.004803          -0.024264
# capacity_change_percent         0.195541           0.019629
# ratio_change_percent           -0.049267          -0.031054
# project_count                   1.000000           0.634951
# total_investments               0.634951           1.000000

# %%
from matplotlib.artist import setp
pd.plotting.scatter_matrix(df_gen_cap_inv,figsize=(14,8),diagonal='hist')
plt.show()
